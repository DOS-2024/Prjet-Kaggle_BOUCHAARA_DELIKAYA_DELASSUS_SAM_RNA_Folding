# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
df_train = pd.read_csv('df_train_filtered.csv')
df_train.head()
# Out:
#                                             sequence experiment_type  \
# 0  GGGAACGACUCGAGUAGAGUCGAAAAUGAAUAAGCAUGCAUUCCAC...         DMS_MaP
# 1  GGGAACGACUCGAGUAGAGUCGAAAAAUGACAUGUAUAUUCAGGCA...         DMS_MaP
# 2  GGGAACGACUCGAGUAGAGUCGAAAAUAGGCAAAUCCGCAGAUCUA...         2A3_MaP
# 3  GGGAACGACUCGAGUAGAGUCGAAAAUUCGUUUUACAACAAAGGUU...         2A3_MaP
# 4  GGGAACGACUCGAGUAGAGUCGAAAAGAGGGUUGCAAGAGCCUCAA...         2A3_MaP
#
#    signal_to_noise  reactivity_0001  reactivity_0002  reactivity_0003  \
# 0            1.276              NaN              NaN              NaN
# 1            1.102              NaN              NaN              NaN
# 2            5.795              NaN              NaN              NaN
# 3            1.003              NaN              NaN              NaN
# 4            5.744              NaN              NaN              NaN
#
#    reactivity_0004  reactivity_0005  reactivity_0006  reactivity_0007  ...  \
# 0              NaN              NaN              NaN              NaN  ...
# 1              NaN              NaN              NaN              NaN  ...
# 2              NaN              NaN              NaN              NaN  ...
# 3              NaN              NaN              NaN              NaN  ...
# 4              NaN              NaN              NaN              NaN  ...
#
#    reactivity_0197  reactivity_0198  reactivity_0199  reactivity_0200  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    reactivity_0201  reactivity_0202  reactivity_0203  reactivity_0204  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    reactivity_0205  reactivity_0206
# 0              NaN              NaN
# 1              NaN              NaN
# 2              NaN              NaN
# 3              NaN              NaN
# 4              NaN              NaN
#
# [5 rows x 209 columns]

# %%
df_val = pd.read_csv('df_val_filtered.csv')
df_val.head()
# Out:
#                                             sequence experiment_type  \
# 0  GGGAACGACUCGAGUAGAGUCGAAAAUAUACAUAAGAAGUCCGCGC...         DMS_MaP
# 1  GGGAACGACUCGAGUAGAGUCGAAAAUCUUCUUUCCCUUCUCUCGU...         DMS_MaP
# 2  GGGAACGACUCGAGUAGAGUCGAAAACUGGCGUAGGCGGAUUCGCG...         2A3_MaP
# 3  GGGAACGACUCGAGUAGAGUCGAAAAGUCUCCCGAUUCGUCGGGAG...         2A3_MaP
# 4  GGGAACGACUCGAGUAGAGUCGAAAAUGUUGUAGAUUCUUAUUAUU...         DMS_MaP
#
#    signal_to_noise  reactivity_0001  reactivity_0002  reactivity_0003  \
# 0            1.028              NaN              NaN              NaN
# 1           11.417              NaN              NaN              NaN
# 2           10.380              NaN              NaN              NaN
# 3            7.738              NaN              NaN              NaN
# 4            1.677              NaN              NaN              NaN
#
#    reactivity_0004  reactivity_0005  reactivity_0006  reactivity_0007  ...  \
# 0              NaN              NaN              NaN              NaN  ...
# 1              NaN              NaN              NaN              NaN  ...
# 2              NaN              NaN              NaN              NaN  ...
# 3              NaN              NaN              NaN              NaN  ...
# 4              NaN              NaN              NaN              NaN  ...
#
#    reactivity_0197  reactivity_0198  reactivity_0199  reactivity_0200  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    reactivity_0201  reactivity_0202  reactivity_0203  reactivity_0204  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    reactivity_0205  reactivity_0206
# 0              NaN              NaN
# 1              NaN              NaN
# 2              NaN              NaN
# 3              NaN              NaN
# 4              NaN              NaN
#
# [5 rows x 209 columns]

# %%
df_test = pd.read_csv('df_test_filtered.csv')
df_test.head()
# Out:
#                                             sequence experiment_type  \
# 0  GGGAACGACUCGAGUAGAGUCGAAAAUGAUCUUCUCUCUUCACCCC...         2A3_MaP
# 1  GGGAACGACUCGAGUAGAGUCGAAAAUUGGAUAAAAUACCUUCCAA...         DMS_MaP
# 2  GGGAACGACUCGAGUAGAGUCGAAAAACCUUGACCAGGGCUUUAAC...         DMS_MaP
# 3  GGGAACGACUCGAGUAGAGUCGAAAAAGACUUUUAUGACUUUGCUG...         DMS_MaP
# 4  GGGAACGACUCGAGUAGAGUCGAAAAGAUAUGGAUUAGAGGGAGAG...         DMS_MaP
#
#    signal_to_noise  reactivity_0001  reactivity_0002  reactivity_0003  \
# 0            1.113              NaN              NaN              NaN
# 1            1.316              NaN              NaN              NaN
# 2            1.618              NaN              NaN              NaN
# 3            2.308              NaN              NaN              NaN
# 4            8.115              NaN              NaN              NaN
#
#    reactivity_0004  reactivity_0005  reactivity_0006  reactivity_0007  ...  \
# 0              NaN              NaN              NaN              NaN  ...
# 1              NaN              NaN              NaN              NaN  ...
# 2              NaN              NaN              NaN              NaN  ...
# 3              NaN              NaN              NaN              NaN  ...
# 4              NaN              NaN              NaN              NaN  ...
#
#    reactivity_0197  reactivity_0198  reactivity_0199  reactivity_0200  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    reactivity_0201  reactivity_0202  reactivity_0203  reactivity_0204  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    reactivity_0205  reactivity_0206
# 0              NaN              NaN
# 1              NaN              NaN
# 2              NaN              NaN
# 3              NaN              NaN
# 4              NaN              NaN
#
# [5 rows x 209 columns]

# %%
import numpy as np
import pandas as pd

def process_dataframe_fast(df, max_len=457):
    """
    Version optimisée du traitement des séquences :
    - One-hot encoding
    - Normalisation robuste
    - Padding
    - Utilise un dictionnaire indexé plutôt que des filtres dans chaque boucle
    """
    mapping = {'A':0, 'C':1, 'G':2, 'U':3}
    factor = 1.4826
    
    # 1. Indexation des données pour accès rapide
    grouped = df.groupby(['sequence', 'experiment_type'])
    dms_dict = {}
    a3_dict = {}
    
    for (seq, exp), subdf in grouped:
        row = subdf.iloc[0]
        values = [row[f'reactivity_{i+1:04d}'] for i in range(len(seq))]
        if exp == 'DMS_MaP':
            dms_dict[seq] = np.array(values)
        elif exp == '2A3_MaP':
            a3_dict[seq] = np.array(values)
    
    unique_sequences = df['sequence'].unique()
    
    # 2. Pré-collecte des valeurs pour normalisation
    dms_values = np.concatenate([v[~np.isnan(v)] for v in dms_dict.values() if v is not None])
    a3_values  = np.concatenate([v[~np.isnan(v)] for v in a3_dict.values() if v is not None])
    
    dms_median = np.nanmedian(dms_values)
    dms_mad    = np.nanmedian(np.abs(dms_values - dms_median))
    a3_median  = np.nanmedian(a3_values)
    a3_mad     = np.nanmedian(np.abs(a3_values - a3_median))
    
    print(f"[INFO] DMS median={dms_median:.3f}, MAD={dms_mad:.3f}")
    print(f"[INFO] 2A3 median={a3_median:.3f}, MAD={a3_mad:.3f}")
    
    # 3. Création du tensor par séquence
    result_list = []
    for seq in unique_sequences:
        seq_len = len(seq)
        tensor = np.zeros((max_len, 6), dtype=np.float32)
        
        # One-hot encoding rapide
        for i, nuc in enumerate(seq):
            if i >= max_len: break
            if nuc in mapping:
                tensor[i, mapping[nuc]] = 1
        
        # Ajout réactivités normalisées
        dms_vals = dms_dict.get(seq, np.full(seq_len, np.nan))
        a3_vals  = a3_dict.get(seq, np.full(seq_len, np.nan))
        
        if len(dms_vals) > 0:
            dms_norm = np.nan_to_num((dms_vals - dms_median) / (factor * dms_mad))
            tensor[:min(seq_len, max_len), 4] = dms_norm[:max_len]
        if len(a3_vals) > 0:
            a3_norm = np.nan_to_num((a3_vals - a3_median) / (factor * a3_mad))
            tensor[:min(seq_len, max_len), 5] = a3_norm[:max_len]
        
        result_list.append(tensor)
    
    return result_list

# %%
# 🟡 2. Transformation des trois jeux
ohe_train_data = process_dataframe_fast(df_train)
ohe_test_data  = process_dataframe_fast(df_test)
ohe_val_data   = process_dataframe_fast(df_val)

print(f"Train : {len(ohe_train_data)} séquences")
print(f"Test  : {len(ohe_test_data)} séquences")
print(f"Val   : {len(ohe_val_data)} séquences")
# Out:
# [INFO] DMS median=0.123, MAD=0.133
# [INFO] 2A3 median=0.212, MAD=0.212
# [INFO] DMS median=0.123, MAD=0.133
# [INFO] 2A3 median=0.213, MAD=0.213
# [INFO] DMS median=0.123, MAD=0.133
# [INFO] 2A3 median=0.212, MAD=0.212
# Train : 117584 séquences
# Test  : 20158 séquences
# Val   : 30236 séquences

# %%
import numpy as np

def split_X_Y(tensor_list):
    """
    Sépare X (features) et Y (targets) à partir d'une liste de tableaux numpy.
    Chaque tableau est de la forme (seq_len, 6) : 4 colonnes one-hot + 2 réactivités.
    
    Args:
        tensor_list (list of np.ndarray): Liste de séquences traitées.
    
    Returns:
        X: np.ndarray de shape (n_samples, seq_len, 4)
        Y: np.ndarray de shape (n_samples, seq_len, 2)
    """
    X_list = []
    Y_list = []
    
    for tensor in tensor_list:
        X_list.append(tensor[:, :4])  # 4 colonnes de one-hot
        Y_list.append(tensor[:, 4:])  # 2 colonnes de réactivités normalisées
    
    X = np.stack(X_list)
    Y = np.stack(Y_list)
    return X, Y

# %%
X_train, Y_train = split_X_Y(ohe_train_data)
X_val, Y_val = split_X_Y(ohe_val_data)
X_test, Y_test = split_X_Y(ohe_test_data)

print("X_train:", X_train.shape)
print("Y_train:", Y_train.shape)
print("X_val:", X_val.shape)
print("Y_val:", Y_val.shape)
print("X_test:", X_test.shape)
print("Y_test:", Y_test.shape)
# Out:
# X_train: (117584, 457, 4)
# Y_train: (117584, 457, 2)
# X_val: (30236, 457, 4)
# Y_val: (30236, 457, 2)
# X_test: (20158, 457, 4)
# Y_test: (20158, 457, 2)

# %%
import torch



if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("🚀 MPS activé : entraînement sur GPU Apple Silicon")
else:
    device = torch.device("cpu")
    print("⚠️ Pas de MPS détecté, fallback CPU")

print(f"Device utilisé : {device}")
# Out:
# 🚀 MPS activé : entraînement sur GPU Apple Silicon
# Device utilisé : mps

# %%
# -------------------------------
# Métriques
# -------------------------------
def mae(y_pred, y_true):
    return torch.mean(torch.abs(y_pred - y_true))

def rmse(y_pred, y_true):
    return torch.sqrt(torch.mean((y_pred - y_true)**2))

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from tqdm import tqdm
import numpy as np

class LstmPlusConv(nn.Module):
    def __init__(self, input_size=(457, 4), output_size=2, hidden_size=64):
        super().__init__()
        self.lstm1 = nn.LSTM(input_size[1], hidden_size, batch_first=True, bidirectional=True)
        self.lstm2 = nn.LSTM(hidden_size * 2, 32, batch_first=True)
        self.dropout = nn.Dropout(0.1)
        self.conv1 = nn.Conv1d(32, 64, kernel_size=3, padding='same')
        self.conv2 = nn.Conv1d(64, 128, kernel_size=3, padding='same', dilation=2)
        self.conv3 = nn.Conv1d(128, 256, kernel_size=3, padding='same', dilation=4)
        self.fc = nn.Linear(256, output_size)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x, _ = self.lstm2(x)
        x = self.dropout(x)
        x = x.transpose(1, 2)          # (batch, channels, seq_len)
        x = torch.relu(self.conv1(x))
        x = torch.relu(self.conv2(x))
        x = torch.relu(self.conv3(x))
        x = x.transpose(1, 2)          # (batch, seq_len, channels)
        x = self.fc(x)                 # (batch, seq_len, output_size)
        return x
# Exemple d'initialisation
#model = LstmPlusConv(input_size=(457, 4), output_size=2, hidden_size=32).to("mps")
#print(model)

# %%
# -------------------------------
# Dataset factice (exemple)
# -------------------------------
batch_size = 128
seq_len, feature_dim = 457, 4
output_dim = 2
num_samples = 128

X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
Y_train_t = torch.tensor(Y_train, dtype=torch.float32).to(device)

X_val_t = torch.tensor(X_val, dtype=torch.float32).to(device)
Y_val_t = torch.tensor(Y_val, dtype=torch.float32).to(device)

X_test_t = torch.tensor(X_test, dtype=torch.float32).to(device)
Y_test_t = torch.tensor(Y_test, dtype=torch.float32).to(device)

# -------------------------------
# 3️⃣ DataLoader
# -------------------------------
batch_size = 128
train_dataset = TensorDataset(X_train_t, Y_train_t)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = TensorDataset(X_val_t, Y_val_t)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
test_dataset = TensorDataset(X_test_t, Y_test_t)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
print("Nombre de batches train :", len(train_loader))
print("Nombre de batches val   :", len(val_loader))
# Out:
# Nombre de batches train : 919
# Nombre de batches val   : 237

# %%
print("X_train shape:", X_train.shape)
print("Y_train shape:", Y_train.shape)
# Out:
# X_train shape: (117584, 457, 4)
# Y_train shape: (117584, 457, 2)

# %%
# 4️⃣ Masques pour ignore padding
# -------------------------------
def create_mask(y):
    # True où les valeurs sont valides
    return (y != 0).float()

# -------------------------------
# 5️⃣ Metrics masquées
# -------------------------------
def masked_mse(y_pred, y_true):
    mask = create_mask(y_true)
    mse = ((y_pred - y_true) ** 2 * mask).sum() / mask.sum()
    return mse

# %%
# -------------------------------
# Initialisation modèle, loss, optim
# -------------------------------
device = "mps" if torch.backends.mps.is_available() else "cpu"

model = LstmPlusConv().to(device)
criterion = nn.MSELoss()
optimizer = optim.AdamW(model.parameters(), lr=1e-3)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=3, factor=0.5)

# %%
# -----------------------------------------
# Boucle d'entraînement complète
# -----------------------------------------
num_epochs = 50
patience = 5
best_val_loss = float('inf')
patience_counter = 0

history = {
    "train_loss": [], "train_mae": [], "train_rmse": [],
    "val_loss": [], "val_mae": [], "val_rmse": []
}

for epoch in range(num_epochs):
    # -----------------------------
    # Phase d'entraînement
    # -----------------------------
    model.train()
    train_loss, train_mae, train_rmse_val = 0, 0, 0

    for batch_x, batch_y in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Train]"):
        batch_x, batch_y = batch_x.to(device), batch_y.to(device)
        optimizer.zero_grad()
        outputs = model(batch_x)

        loss = criterion(outputs, batch_y)
        loss.backward()
        optimizer.step()

        # Accumulation des métriques
        train_loss += loss.item()
        train_mae += mae(outputs, batch_y).item()
        train_rmse_val += rmse(outputs, batch_y).item()

    train_loss /= len(train_loader)
    train_mae /= len(train_loader)
    train_rmse_val /= len(train_loader)

    # -----------------------------
    # Phase de validation
    # -----------------------------
    model.eval()
    val_loss, val_mae, val_rmse_val = 0, 0, 0

    with torch.no_grad():
        for batch_x, batch_y in val_loader:
            batch_x, batch_y = batch_x.to(device), batch_y.to(device)
            outputs = model(batch_x)
            loss = criterion(outputs, batch_y)

            val_loss += loss.item()
            val_mae += mae(outputs, batch_y).item()
            val_rmse_val += rmse(outputs, batch_y).item()

    val_loss /= len(val_loader)
    val_mae /= len(val_loader)
    val_rmse_val /= len(val_loader)

    # -----------------------------
    # Scheduler & sauvegarde
    # -----------------------------
    scheduler.step(val_loss)

    history["train_loss"].append(train_loss)
    history["train_mae"].append(train_mae)
    history["train_rmse"].append(train_rmse_val)

    history["val_loss"].append(val_loss)
    history["val_mae"].append(val_mae)
    history["val_rmse"].append(val_rmse_val)

    # -----------------------------
    # Affichage des résultats
    # -----------------------------
    print(f"Epoch [{epoch+1}/{num_epochs}] "
          f"Train -> Loss: {train_loss:.4f}, MAE: {train_mae:.4f}, RMSE: {train_rmse_val:.4f} | "
          f"Val -> Loss: {val_loss:.4f}, MAE: {val_mae:.4f}, RMSE: {val_rmse_val:.4f}")

    # -----------------------------
    # Early stopping
    # -----------------------------
    if val_loss < best_val_loss - 1e-4:
        best_val_loss = val_loss
        patience_counter = 0
        best_model_state = model.state_dict()
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print(f"⏹️ Early stopping triggered after {epoch+1} epochs.")
            break

print("✅ Entraînement terminé")
# Out:
# Epoch 1/50 [Train]: 100%|██████████| 919/919 [01:29<00:00, 10.29it/s]
# Epoch [1/50] Train -> Loss: 0.9731, MAE: 0.2746, RMSE: 0.9856 | Val -> Loss: 0.9390, MAE: 0.2650, RMSE: 0.9683
# Epoch 2/50 [Train]: 100%|██████████| 919/919 [01:30<00:00, 10.15it/s]
# Epoch [2/50] Train -> Loss: 0.9531, MAE: 0.2708, RMSE: 0.9754 | Val -> Loss: 0.9235, MAE: 0.2679, RMSE: 0.9602
# Epoch 3/50 [Train]: 100%|██████████| 919/919 [01:35<00:00,  9.60it/s]
# Epoch [3/50] Train -> Loss: 0.9372, MAE: 0.2663, RMSE: 0.9672 | Val -> Loss: 0.9145, MAE: 0.2636, RMSE: 0.9555
# Epoch 4/50 [Train]: 100%|██████████| 919/919 [01:40<00:00,  9.13it/s]
# Epoch [4/50] Train -> Loss: 0.9230, MAE: 0.2629, RMSE: 0.9598 | Val -> Loss: 0.9036, MAE: 0.2595, RMSE: 0.9498
# Epoch 5/50 [Train]: 100%|██████████| 919/919 [01:38<00:00,  9.29it/s]
# Epoch [5/50] Train -> Loss: 0.9161, MAE: 0.2612, RMSE: 0.9562 | Val -> Loss: 0.8945, MAE: 0.2592, RMSE: 0.9450
# Epoch 6/50 [Train]: 100%|██████████| 919/919 [01:39<00:00,  9.27it/s]
# Epoch [6/50] Train -> Loss: 0.9055, MAE: 0.2585, RMSE: 0.9507 | Val -> Loss: 0.8899, MAE: 0.2550, RMSE: 0.9426
# Epoch 7/50 [Train]: 100%|██████████| 919/919 [01:50<00:00,  8.33it/s]
# Epoch [7/50] Train -> Loss: 0.8984, MAE: 0.2570, RMSE: 0.9471 | Val -> Loss: 0.8824, MAE: 0.2541, RMSE: 0.9386
# Epoch 8/50 [Train]: 100%|██████████| 919/919 [01:44<00:00,  8.78it/s]
# Epoch [8/50] Train -> Loss: 0.8914, MAE: 0.2558, RMSE: 0.9433 | Val -> Loss: 0.8780, MAE: 0.2529, RMSE: 0.9363
# Epoch 9/50 [Train]: 100%|██████████| 919/919 [01:50<00:00,  8.31it/s]
# Epoch [9/50] Train -> Loss: 0.8852, MAE: 0.2548, RMSE: 0.9400 | Val -> Loss: 0.8759, MAE: 0.2535, RMSE: 0.9352
# Epoch 10/50 [Train]: 100%|██████████| 919/919 [01:47<00:00,  8.56it/s]
# Epoch [10/50] Train -> Loss: 0.8792, MAE: 0.2538, RMSE: 0.9369 | Val -> Loss: 0.8677, MAE: 0.2517, RMSE: 0.9308
# Epoch 11/50 [Train]: 100%|██████████| 919/919 [01:47<00:00,  8.59it/s]
# Epoch [11/50] Train -> Loss: 0.8735, MAE: 0.2528, RMSE: 0.9339 | Val -> Loss: 0.8654, MAE: 0.2526, RMSE: 0.9296
# Epoch 12/50 [Train]: 100%|██████████| 919/919 [01:42<00:00,  8.95it/s]
# Epoch [12/50] Train -> Loss: 0.8694, MAE: 0.2522, RMSE: 0.9316 | Val -> Loss: 0.8568, MAE: 0.2504, RMSE: 0.9249
# Epoch 13/50 [Train]: 100%|██████████| 919/919 [01:35<00:00,  9.60it/s]
# Epoch [13/50] Train -> Loss: 0.8673, MAE: 0.2523, RMSE: 0.9305 | Val -> Loss: 0.9084, MAE: 0.2752, RMSE: 0.9524
# Epoch 14/50 [Train]: 100%|██████████| 919/919 [01:38<00:00,  9.33it/s]
# Epoch [14/50] Train -> Loss: 0.8792, MAE: 0.2567, RMSE: 0.9370 | Val -> Loss: 0.8748, MAE: 0.2538, RMSE: 0.9346
# Epoch 15/50 [Train]: 100%|██████████| 919/919 [01:41<00:00,  9.07it/s]
# Epoch [15/50] Train -> Loss: 0.8656, MAE: 0.2532, RMSE: 0.9296 | Val -> Loss: 0.8574, MAE: 0.2539, RMSE: 0.9253
# Epoch 16/50 [Train]: 100%|██████████| 919/919 [01:49<00:00,  8.39it/s]
# Epoch [16/50] Train -> Loss: 0.8603, MAE: 0.2519, RMSE: 0.9268 | Val -> Loss: 0.8552, MAE: 0.2536, RMSE: 0.9241
# Epoch 17/50 [Train]: 100%|██████████| 919/919 [01:45<00:00,  8.71it/s]
# Epoch [17/50] Train -> Loss: 0.8555, MAE: 0.2508, RMSE: 0.9242 | Val -> Loss: 0.8490, MAE: 0.2495, RMSE: 0.9207
# Epoch 18/50 [Train]: 100%|██████████| 919/919 [01:44<00:00,  8.80it/s]
# Epoch [18/50] Train -> Loss: 0.8509, MAE: 0.2499, RMSE: 0.9217 | Val -> Loss: 0.8446, MAE: 0.2498, RMSE: 0.9183
# Epoch 19/50 [Train]: 100%|██████████| 919/919 [01:37<00:00,  9.47it/s]
# Epoch [19/50] Train -> Loss: 0.8477, MAE: 0.2494, RMSE: 0.9200 | Val -> Loss: 0.8421, MAE: 0.2474, RMSE: 0.9170
# Epoch 20/50 [Train]: 100%|██████████| 919/919 [01:39<00:00,  9.28it/s]
# Epoch [20/50] Train -> Loss: 0.8447, MAE: 0.2489, RMSE: 0.9183 | Val -> Loss: 0.8401, MAE: 0.2469, RMSE: 0.9158
# Epoch 21/50 [Train]: 100%|██████████| 919/919 [01:34<00:00,  9.68it/s]
# Epoch [21/50] Train -> Loss: 0.8419, MAE: 0.2485, RMSE: 0.9168 | Val -> Loss: 0.8347, MAE: 0.2465, RMSE: 0.9129
# Epoch 22/50 [Train]: 100%|██████████| 919/919 [01:35<00:00,  9.62it/s]
# Epoch [22/50] Train -> Loss: 0.8387, MAE: 0.2482, RMSE: 0.9151 | Val -> Loss: 0.8354, MAE: 0.2467, RMSE: 0.9133
# Epoch 23/50 [Train]: 100%|██████████| 919/919 [01:38<00:00,  9.29it/s]
# Epoch [23/50] Train -> Loss: 0.8361, MAE: 0.2478, RMSE: 0.9137 | Val -> Loss: 0.8333, MAE: 0.2470, RMSE: 0.9122
# Epoch 24/50 [Train]: 100%|██████████| 919/919 [01:38<00:00,  9.29it/s]
# Epoch [24/50] Train -> Loss: 0.8330, MAE: 0.2474, RMSE: 0.9119 | Val -> Loss: 0.8312, MAE: 0.2468, RMSE: 0.9110
# Epoch 25/50 [Train]: 100%|██████████| 919/919 [01:38<00:00,  9.29it/s]
# Epoch [25/50] Train -> Loss: 0.8312, MAE: 0.2473, RMSE: 0.9110 | Val -> Loss: 0.8311, MAE: 0.2474, RMSE: 0.9110
# Epoch 26/50 [Train]: 100%|██████████| 919/919 [01:43<00:00,  8.88it/s]
# Epoch [26/50] Train -> Loss: 0.8288, MAE: 0.2469, RMSE: 0.9097 | Val -> Loss: 0.8286, MAE: 0.2484, RMSE: 0.9096
# Epoch 27/50 [Train]: 100%|██████████| 919/919 [01:54<00:00,  7.99it/s]
# Epoch [27/50] Train -> Loss: 0.8255, MAE: 0.2465, RMSE: 0.9078 | Val -> Loss: 0.8267, MAE: 0.2454, RMSE: 0.9085
# Epoch 28/50 [Train]: 100%|██████████| 919/919 [01:56<00:00,  7.89it/s]
# Epoch [28/50] Train -> Loss: 0.8235, MAE: 0.2463, RMSE: 0.9067 | Val -> Loss: 0.8242, MAE: 0.2441, RMSE: 0.9072
# Epoch 29/50 [Train]: 100%|██████████| 919/919 [01:46<00:00,  8.62it/s]
# Epoch [29/50] Train -> Loss: 0.8214, MAE: 0.2460, RMSE: 0.9056 | Val -> Loss: 0.8220, MAE: 0.2445, RMSE: 0.9060
# Epoch 30/50 [Train]: 100%|██████████| 919/919 [01:57<00:00,  7.80it/s]
# Epoch [30/50] Train -> Loss: 0.8192, MAE: 0.2457, RMSE: 0.9043 | Val -> Loss: 0.8239, MAE: 0.2455, RMSE: 0.9070
# Epoch 31/50 [Train]: 100%|██████████| 919/919 [01:49<00:00,  8.41it/s]
# Epoch [31/50] Train -> Loss: 0.8174, MAE: 0.2455, RMSE: 0.9034 | Val -> Loss: 0.8196, MAE: 0.2441, RMSE: 0.9046
# Epoch 32/50 [Train]: 100%|██████████| 919/919 [02:02<00:00,  7.48it/s]
# Epoch [32/50] Train -> Loss: 0.8152, MAE: 0.2452, RMSE: 0.9022 | Val -> Loss: 0.8202, MAE: 0.2451, RMSE: 0.9050
# Epoch 33/50 [Train]: 100%|██████████| 919/919 [02:01<00:00,  7.57it/s]
# Epoch [33/50] Train -> Loss: 0.8133, MAE: 0.2449, RMSE: 0.9011 | Val -> Loss: 0.8177, MAE: 0.2430, RMSE: 0.9035
# Epoch 34/50 [Train]: 100%|██████████| 919/919 [01:56<00:00,  7.89it/s]
# Epoch [34/50] Train -> Loss: 0.8113, MAE: 0.2447, RMSE: 0.9000 | Val -> Loss: 0.8172, MAE: 0.2452, RMSE: 0.9033
# Epoch 35/50 [Train]: 100%|██████████| 919/919 [01:54<00:00,  8.03it/s]
# Epoch [35/50] Train -> Loss: 0.8173, MAE: 0.2460, RMSE: 0.9033 | Val -> Loss: 0.8187, MAE: 0.2431, RMSE: 0.9041
# Epoch 36/50 [Train]: 100%|██████████| 919/919 [01:53<00:00,  8.11it/s]
# Epoch [36/50] Train -> Loss: 0.8083, MAE: 0.2444, RMSE: 0.8984 | Val -> Loss: 0.8148, MAE: 0.2439, RMSE: 0.9020
# Epoch 37/50 [Train]: 100%|██████████| 919/919 [01:52<00:00,  8.14it/s]
# Epoch [37/50] Train -> Loss: 0.8063, MAE: 0.2441, RMSE: 0.8973 | Val -> Loss: 0.8139, MAE: 0.2433, RMSE: 0.9015
# Epoch 38/50 [Train]: 100%|██████████| 919/919 [01:49<00:00,  8.42it/s]
# Epoch [38/50] Train -> Loss: 0.8053, MAE: 0.2439, RMSE: 0.8967 | Val -> Loss: 0.8106, MAE: 0.2440, RMSE: 0.8996
# Epoch 39/50 [Train]: 100%|██████████| 919/919 [01:55<00:00,  7.98it/s]
# Epoch [39/50] Train -> Loss: 0.8034, MAE: 0.2437, RMSE: 0.8957 | Val -> Loss: 0.8100, MAE: 0.2430, RMSE: 0.8993
# Epoch 40/50 [Train]: 100%|██████████| 919/919 [01:50<00:00,  8.31it/s]
# Epoch [40/50] Train -> Loss: 0.8020, MAE: 0.2436, RMSE: 0.8949 | Val -> Loss: 0.8100, MAE: 0.2435, RMSE: 0.8993
# Epoch 41/50 [Train]: 100%|██████████| 919/919 [01:47<00:00,  8.52it/s]
# Epoch [41/50] Train -> Loss: 0.8095, MAE: 0.2462, RMSE: 0.8989 | Val -> Loss: 0.8105, MAE: 0.2421, RMSE: 0.8996
# Epoch 42/50 [Train]: 100%|██████████| 919/919 [01:46<00:00,  8.60it/s]
# Epoch [42/50] Train -> Loss: 0.8000, MAE: 0.2434, RMSE: 0.8937 | Val -> Loss: 0.8080, MAE: 0.2420, RMSE: 0.8982
# Epoch 43/50 [Train]: 100%|██████████| 919/919 [01:51<00:00,  8.26it/s]
# Epoch [43/50] Train -> Loss: 0.7974, MAE: 0.2430, RMSE: 0.8923 | Val -> Loss: 0.8092, MAE: 0.2443, RMSE: 0.8989
# Epoch 44/50 [Train]: 100%|██████████| 919/919 [01:46<00:00,  8.59it/s]
# Epoch [44/50] Train -> Loss: 0.7966, MAE: 0.2429, RMSE: 0.8918 | Val -> Loss: 0.8062, MAE: 0.2428, RMSE: 0.8972
# Epoch 45/50 [Train]: 100%|██████████| 919/919 [01:47<00:00,  8.58it/s]
# Epoch [45/50] Train -> Loss: 0.7959, MAE: 0.2429, RMSE: 0.8914 | Val -> Loss: 0.8046, MAE: 0.2419, RMSE: 0.8963
# Epoch 46/50 [Train]: 100%|██████████| 919/919 [01:50<00:00,  8.28it/s]
# Epoch [46/50] Train -> Loss: 0.7949, MAE: 0.2427, RMSE: 0.8909 | Val -> Loss: 0.8056, MAE: 0.2435, RMSE: 0.8969
# Epoch 47/50 [Train]: 100%|██████████| 919/919 [01:55<00:00,  7.96it/s]
# Epoch [47/50] Train -> Loss: 0.7932, MAE: 0.2425, RMSE: 0.8899 | Val -> Loss: 0.8061, MAE: 0.2439, RMSE: 0.8971
# Epoch 48/50 [Train]: 100%|██████████| 919/919 [01:49<00:00,  8.40it/s]
# Epoch [48/50] Train -> Loss: 0.7930, MAE: 0.2425, RMSE: 0.8898 | Val -> Loss: 0.8047, MAE: 0.2419, RMSE: 0.8963
# Epoch 49/50 [Train]: 100%|██████████| 919/919 [01:46<00:00,  8.61it/s]
# Epoch [49/50] Train -> Loss: 0.7914, MAE: 0.2423, RMSE: 0.8889 | Val -> Loss: 0.8014, MAE: 0.2419, RMSE: 0.8945
# Epoch 50/50 [Train]: 100%|██████████| 919/919 [01:47<00:00,  8.55it/s]
# Epoch [50/50] Train -> Loss: 0.7908, MAE: 0.2422, RMSE: 0.8886 | Val -> Loss: 0.8097, MAE: 0.2417, RMSE: 0.8991
# ✅ Entraînement terminé

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# -------------------------------
# Fonction pour afficher les courbes d'entraînement
# -------------------------------
def plot_training_history_torch(train_losses, val_losses, train_maes=None, val_maes=None,
                                train_rmses=None, val_rmses=None):
    # corps de la fonction inchangé

    """
    history : dictionnaire retourné par train_model_advanced
              doit contenir au moins 'train_loss' et 'val_loss'
              peut contenir 'train_mae', 'val_mae', 'train_rmse', 'val_rmse'
    """
    metrics = ['Loss', 'MAE', 'RMSE']
    fig_idx = 1
    n_metrics = 1  # au moins la Loss
    if 'train_mae' in history and 'val_mae' in history:
        n_metrics += 1
    if 'train_rmse' in history and 'val_rmse' in history:
        n_metrics += 1

    plt.figure(figsize=(6 * n_metrics, 5))
    
    # --- Loss ---
    plt.subplot(1, n_metrics, fig_idx)
    plt.plot(history['train_loss'], label='Train Loss', color='blue')
    plt.plot(history['val_loss'], label='Val Loss', color='orange')
    plt.title('Courbe de Loss (MSE)')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    fig_idx += 1

    # --- MAE ---
    if 'train_mae' in history and 'val_mae' in history:
        plt.subplot(1, n_metrics, fig_idx)
        plt.plot(history['train_mae'], label='Train MAE', color='blue')
        plt.plot(history['val_mae'], label='Val MAE', color='orange')
        plt.title('Courbe de MAE')
        plt.xlabel('Epoch')
        plt.ylabel('MAE')
        plt.legend()
        plt.grid(True)
        fig_idx += 1

    # --- RMSE ---
    if 'train_rmse' in history and 'val_rmse' in history:
        plt.subplot(1, n_metrics, fig_idx)
        plt.plot(history['train_rmse'], label='Train RMSE', color='blue')
        plt.plot(history['val_rmse'], label='Val RMSE', color='orange')
        plt.title('Courbe de RMSE')
        plt.xlabel('Epoch')
        plt.ylabel('RMSE')
        plt.legend()
        plt.grid(True)

    plt.tight_layout()
    plt.show()

# %%
# -------------------------------
# 2️⃣ Prédiction vs Réalité pour une séquence
# -------------------------------
def plot_pred_vs_true_torch(y_true, y_pred, seq_index=0, target=0):
    y_true = y_true.cpu().numpy()
    y_pred = y_pred.cpu().numpy()

    true_seq = y_true[seq_index, :, target]
    pred_seq = y_pred[seq_index, :, target]

    # masque padding
    mask = true_seq != 0
    true_seq = true_seq[mask]
    pred_seq = pred_seq[mask]

    plt.figure(figsize=(14, 5))
    plt.plot(true_seq, label='Vraie réactivité', color='green')
    plt.plot(pred_seq, label='Prédiction', color='red', alpha=0.7)
    plt.title(f"Réactivité réelle vs prédite — Séquence {seq_index} — Target {target}")
    plt.xlabel("Position")
    plt.ylabel("Réactivité")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# -------------------------------
# 3️⃣ Distribution globale des erreurs
# -------------------------------
def plot_error_distribution_torch(y_true, y_pred, bins=100):
    """
    Affiche la distribution des erreurs (y_pred - y_true) pour PyTorch tensors.
    
    y_true : tensor (batch ou dataset)
    y_pred : tensor (batch ou dataset)
    bins   : nombre de bins pour l'histogramme
    """
    # Convertir en numpy et flatten
    y_true = y_true.detach().cpu().numpy().flatten()
    y_pred = y_pred.detach().cpu().numpy().flatten()

    # Calcul des erreurs
    errors = y_pred - y_true

    # Supprimer NaN et inf
    errors = errors[np.isfinite(errors)]

    plt.figure(figsize=(10, 5))
    sns.histplot(errors, bins=bins, kde=True, color='purple', stat='density', alpha=0.7)
    plt.title('Distribution des erreurs (y_pred - y_true)')
    plt.xlabel('Erreur')
    plt.ylabel('Densité')
    plt.grid(True)
    plt.show()

# %%
# -------------------------------
# 4️⃣ Heatmap sur plusieurs séquences
# -------------------------------
def plot_heatmap_sequences_torch(y, n_sequences=30, target=0, title="Réactivité", annot=False, fmt=".2f"):
    """
    Affiche un heatmap des séquences pour un target donné.

    y           : tensor PyTorch [batch, seq_len, n_targets]
    n_sequences : nombre de séquences à afficher
    target      : index de la dimension target à afficher
    title       : titre du graphique
    annot       : afficher les valeurs sur le heatmap
    fmt         : format d'affichage si annot=True
    """
    # Conversion en numpy
    y = y.detach().cpu().numpy()

    # Vérification du target
    n_targets = y.shape[2]
    if target >= n_targets:
        raise ValueError(f"Target {target} est hors limite (n_targets={n_targets})")

    # Sélection des séquences
    subset = y[:n_sequences, :, target]

    plt.figure(figsize=(15, 8))
    sns.heatmap(subset, cmap="viridis", cbar=True, annot=annot, fmt=fmt)
    plt.title(title)
    plt.xlabel("Position")
    plt.ylabel("Séquence")
    plt.show()

# %%
# Courbes Loss / MAE / RMSE
plot_training_history_torch(
    train_losses=history['train_loss'],
    val_losses=history['val_loss'],
    train_maes=history['train_mae'],
    val_maes=history['val_mae'],
    train_rmses=history['train_rmse'],
    val_rmses=history['val_rmse']
)

# %%
# 🔹 Mettre le modèle en mode évaluation
model.eval()

all_preds = []
all_trues = []

with torch.no_grad():
    for batch_x, batch_y in test_loader:
        batch_x = batch_x.to(device).float()
        batch_y = batch_y.to(device).float()
        
        outputs = model(batch_x)
        
        all_preds.append(outputs.cpu())
        all_trues.append(batch_y.cpu())

# Concaténer tous les batches
y_pred = torch.cat(all_preds, dim=0)
y_true = torch.cat(all_trues, dim=0)

# Créer le masque pour ignorer les padding si nécessaire
mask = create_mask(y_true) if 'create_mask' in globals() else torch.ones_like(y_true)
mask = mask.bool()

# Appliquer le masque
y_pred_masked = y_pred[mask]
y_true_masked = y_true[mask]

# 🔹 Calcul des métriques sur le jeu test
mse = torch.mean((y_pred_masked - y_true_masked)**2).item()
mae = torch.mean(torch.abs(y_pred_masked - y_true_masked)).item()
rmse = torch.sqrt(torch.tensor(mse)).item()

print(f"Test MSE: {mse:.4f}")
print(f"Test MAE: {mae:.4f}")
print(f"Test RMSE: {rmse:.4f}")

# 🔹 Visualisations avec les fonctions définies
plot_pred_vs_true_torch(y_true, y_pred, seq_index=0, target=0)
plot_error_distribution_torch(y_true, y_pred)
plot_heatmap_sequences_torch(y_pred, n_sequences=30, target=0, title="Prédictions sur Test")
# Out:
# Test MSE: 3.6859
# Test MAE: 1.0978
# Test RMSE: 1.9199
